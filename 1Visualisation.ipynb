# %%
MAIN_PATH = "/home/jack/datasets/politycy/"

# %%
# %matplotlib inline
import seaborn as sns
from matplotlib import cm
import pandas as pd

# %%
df = pd.DataFrame.from_csv(MAIN_PATH + "kluby_tytuly.csv")

# %%
# df = df.drop("Mniejszość Niemiecka")

# %%
df = df.divide(df.sum(axis=1), axis=0).transpose()

# %%
fig = df.plot.pie(figsize=(40,60), colormap=cm.Accent, fontsize=25, subplots=True, layout=(3,2), legend=False)

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
c = "Prawo i Sprawiedliwość"
df[c][df[c] != 0].keys()
# Out:
# Index(['doktor', 'doktor habilitowany', 'dyplomowany ekonomista', 'inżynier',
#        'lekarz', 'lekarz dentysta', 'licencjat', 'magister',
#        'magister inżynier', 'magister sztuki', 'matura', 'nic',
#        'studia doktoranckie', 'studia podyplomowe', 'technik'],
#       dtype='object')

# %%
len(df.transpose())
# Out:
# 6

# %%
fig = plt.figure(figsize=(18, 27))
axes = []
for idc, c in enumerate(df):
    axes.append(fig.add_subplot(3, 2, idc+1))
    axes[idc].set_title(c, fontsize=20)
    nonempty_df = df[c][df[c] != 0]
    nonzero_labels = df[c][df[c] != 0].keys()
    cleaned_labels = [l  if l in nonzero_labels else "" for l in df[c].keys()]
    patches = axes[idc].pie(df[c], colors=cm.Accent(np.arange(len(df[c]))/len(df[c])), labels=cleaned_labels)
#     print(set(df[c].keys())

# %%
axes[1]
